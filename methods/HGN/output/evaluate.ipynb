# %%
import torch
# saved = torch.load('./checkpoint/checkpoint_ERM_2.pt')

# %%
import pandas as pd
label = pd.read_table('../../../data/ERM/label.dat.test',header=None)
label
# Out:
#         0   1  2  3
# 0     793 NaN  0  0
# 1     682 NaN  0  1
# 2    2450 NaN  0  0
# 3    1898 NaN  0  0
# 4     936 NaN  0  0
# ..    ...  .. .. ..
# 905  2967 NaN  0  0
# 906  2680 NaN  0  0
# 907  2559 NaN  0  0
# 908  2460 NaN  0  0
# 909   921 NaN  0  0
#
# [910 rows x 4 columns]

# %%
predict = pd.read_table('./save/ERM_2.txt',header=None)
predict[2].value_counts()
# Out:
# 2
# 0    910
# Name: count, dtype: int64

# %%
predict[3].value_counts()
# Out:
# 3
# 0    857
# 1     53
# Name: count, dtype: int64

# %% [markdown]
# ### Load Record

# %%
import pandas as pd
import numpy as np
data = np.load('../save/loss_record.npz')

# %%
import matplotlib.pyplot as plt

plt.plot(data['train'], label='Training Loss')
plt.plot(data['val'], label='Validation Loss')
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.title('Loss over Epoch')

# 显示图形
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

import numpy as np

# 读取预测结果和真实标签
label = np.load('../save01/label.npz')
predict_onehot = label['predict']
groundtruth_onehot = label['val']

# 将one-hot编码的标签转换为0、1、2等标签形式
predict = np.argmax(predict_onehot, axis=1)
groundtruth = np.argmax(groundtruth_onehot, axis=1)

# %%
pd.DataFrame(groundtruth).value_counts()
# Out:
# 0    850
# 1     60
# Name: count, dtype: int64

# %%
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
target_names=['Non-TF','TF']
report=classification_report(groundtruth, predict,target_names=target_names,output_dict=True)
report = pd.DataFrame(report)
report
# Out:
#                Non-TF    TF  accuracy   macro avg  weighted avg
# precision    0.992941   0.9  0.986813    0.946471      0.986813
# recall       0.992941   0.9  0.986813    0.946471      0.986813
# f1-score     0.992941   0.9  0.986813    0.946471      0.986813
# support    850.000000  60.0  0.986813  910.000000    910.000000

# %%
import numpy as np

# 计算混淆矩阵
cm = confusion_matrix(groundtruth, predict)

# 计算每个类别的正确比例
correct_ratios = np.diag(cm) / cm.sum(axis=1)

# 绘制混淆矩阵热图
ax = sns.heatmap(cm, annot=True, fmt='g', xticklabels=target_names, yticklabels=target_names, annot_kws={"fontsize":25})
ax.set_xlabel('Predict', size=20)
ax.set_ylabel('GroundTruth', size=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.gcf().set_size_inches(8, 6)
cax = plt.gcf().axes[-1]
cax.tick_params(labelsize=15)

# 在热图上标出每个类别的正确比例
for i, label in enumerate(target_names):
    ax.annotate(f"({correct_ratios[i]:.2%})", xy=(i+0.5, i+0.8), ha="center", va="center", fontsize=24, color="blue")

plt.show()

# %%
report.to_csv("1.csv",index=False)
